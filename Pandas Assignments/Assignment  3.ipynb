# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Assignment 3
# 1. Import the MELBOURNE_HOUSE_PRICES_LESS.csv dataset
# 2. Extract all the values where price column is not null from the dataset to a new variable
# 3. Extract all the values where price column is null from the dataset to a new variable
# 4. Clean the dataset so it deosn't have any null value again using any method
# 5. Compute the sum, mean of the price column on the dataset
# 6. Get the house with the lowest price and with the highest price

# %%
house_prices = pd.read_csv('C:\Datasets\MELBOURNE_HOUSE_PRICES_LESS.csv')

house_prices.head()
# Out:
#          Suburb           Address  Rooms Type      Price Method   SellerG  \
# 0    Abbotsford     49 Lithgow St      3    h  1490000.0      S    Jellis
# 1    Abbotsford     59A Turner St      3    h  1220000.0      S  Marshall
# 2    Abbotsford     119B Yarra St      3    h  1420000.0      S    Nelson
# 3    Aberfeldie        68 Vida St      3    h  1515000.0      S     Barry
# 4  Airport West  92 Clydesdale Rd      2    h   670000.0      S    Nelson
#
#         Date  Postcode             Regionname  Propertycount  Distance  \
# 0  1/04/2017      3067  Northern Metropolitan           4019       3.0
# 1  1/04/2017      3067  Northern Metropolitan           4019       3.0
# 2  1/04/2017      3067  Northern Metropolitan           4019       3.0
# 3  1/04/2017      3040   Western Metropolitan           1543       7.5
# 4  1/04/2017      3042   Western Metropolitan           3464      10.4
#
#                   CouncilArea
# 0          Yarra City Council
# 1          Yarra City Council
# ...

# %%
# checking the last 5 data
house_prices.tail()
# Out:
#                  Suburb         Address  Rooms Type     Price Method SellerG  \
# 63018     Roxburgh Park       3 Carr Pl      3    h  566000.0      S   Raine
# 63019     Roxburgh Park     9 Parker Ct      3    h  500000.0      S   Raine
# 63020     Roxburgh Park  5 Parkinson Wy      3    h  545000.0      S   Raine
# 63021        Thomastown  3/1 Travers St      3    u       NaN     PI   Barry
# 63022  Williams Landing     1 Diadem Wy      4    h       NaN     SP  Aussie
#
#              Date  Postcode             Regionname  Propertycount  Distance  \
# 63018  31/03/2018      3064  Northern Metropolitan           5833      20.6
# 63019  31/03/2018      3064  Northern Metropolitan           5833      20.6
# 63020  31/03/2018      3064  Northern Metropolitan           5833      20.6
# 63021  31/03/2018      3074  Northern Metropolitan           7955      15.3
# 63022  31/03/2018      3027   Western Metropolitan           1999      17.6
#
#                    CouncilArea
# ...

# %%
# getting information about the data
house_prices.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63023 entries, 0 to 63022
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         63023 non-null  object
#  1   Address        63023 non-null  object
#  2   Rooms          63023 non-null  int64
#  3   Type           63023 non-null  object
#  4   Price          48433 non-null  float64
#  5   Method         63023 non-null  object
#  6   SellerG        63023 non-null  object
#  7   Date           63023 non-null  object
#  8   Postcode       63023 non-null  int64
#  9   Regionname     63023 non-null  object
#  10  Propertycount  63023 non-null  int64
#  11  Distance       63023 non-null  float64
#  12  CouncilArea    63023 non-null  object
# dtypes: float64(2), int64(3), object(8)
# memory usage: 6.3+ MB

# %%
house_prices
# Out:
#                  Suburb           Address  Rooms Type      Price Method  \
# 0            Abbotsford     49 Lithgow St      3    h  1490000.0      S
# 1            Abbotsford     59A Turner St      3    h  1220000.0      S
# 2            Abbotsford     119B Yarra St      3    h  1420000.0      S
# 3            Aberfeldie        68 Vida St      3    h  1515000.0      S
# 4          Airport West  92 Clydesdale Rd      2    h   670000.0      S
# ...                 ...               ...    ...  ...        ...    ...
# 63018     Roxburgh Park         3 Carr Pl      3    h   566000.0      S
# 63019     Roxburgh Park       9 Parker Ct      3    h   500000.0      S
# 63020     Roxburgh Park    5 Parkinson Wy      3    h   545000.0      S
# 63021        Thomastown    3/1 Travers St      3    u        NaN     PI
# 63022  Williams Landing       1 Diadem Wy      4    h        NaN     SP
#
#         SellerG        Date  Postcode             Regionname  Propertycount  \
# ...

# %%
# general overview of the dataset
house_prices.describe()
# Out:
#               Rooms         Price      Postcode  Propertycount      Distance
# count  63023.000000  4.843300e+04  63023.000000   63023.000000  63023.000000
# mean       3.110595  9.978982e+05   3125.673897    7617.728131     12.684829
# std        0.957551  5.934989e+05    125.626877    4424.423167      7.592015
# min        1.000000  8.500000e+04   3000.000000      39.000000      0.000000
# 25%        3.000000  6.200000e+05   3056.000000    4380.000000      7.000000
# 50%        3.000000  8.300000e+05   3107.000000    6795.000000     11.400000
# 75%        4.000000  1.220000e+06   3163.000000   10412.000000     16.700000
# max       31.000000  1.120000e+07   3980.000000   21650.000000     64.100000

# %%
# Extract all the values where price column is not null from the dataset to a new variable
# price_notnull = house_prices[house_prices.notnull()]
# price_notnull
# Out:
#        Suburb  Address  Rooms  Type  Price  Method  SellerG  Date  Postcode  \
# 0        True     True   True  True   True    True     True  True      True
# 1        True     True   True  True   True    True     True  True      True
# 2        True     True   True  True   True    True     True  True      True
# 3        True     True   True  True   True    True     True  True      True
# 4        True     True   True  True   True    True     True  True      True
# ...       ...      ...    ...   ...    ...     ...      ...   ...       ...
# 63018    True     True   True  True   True    True     True  True      True
# 63019    True     True   True  True   True    True     True  True      True
# 63020    True     True   True  True   True    True     True  True      True
# 63021    True     True   True  True  False    True     True  True      True
# 63022    True     True   True  True  False    True     True  True      True
#
#        Regionname  Propertycount  Distance  CouncilArea
# ...

# %%
# Extract all the values where price column is null from the dataset to a new variable
price_isnull = house_prices[house_prices.isnull()]
price_isnull
# Out:
#       Suburb Address  Rooms Type  Price Method SellerG Date  Postcode  \
# 0        NaN     NaN    NaN  NaN    NaN    NaN     NaN  NaN       NaN
# 1        NaN     NaN    NaN  NaN    NaN    NaN     NaN  NaN       NaN
# 2        NaN     NaN    NaN  NaN    NaN    NaN     NaN  NaN       NaN
# 3        NaN     NaN    NaN  NaN    NaN    NaN     NaN  NaN       NaN
# 4        NaN     NaN    NaN  NaN    NaN    NaN     NaN  NaN       NaN
# ...      ...     ...    ...  ...    ...    ...     ...  ...       ...
# 63018    NaN     NaN    NaN  NaN    NaN    NaN     NaN  NaN       NaN
# 63019    NaN     NaN    NaN  NaN    NaN    NaN     NaN  NaN       NaN
# 63020    NaN     NaN    NaN  NaN    NaN    NaN     NaN  NaN       NaN
# 63021    NaN     NaN    NaN  NaN    NaN    NaN     NaN  NaN       NaN
# 63022    NaN     NaN    NaN  NaN    NaN    NaN     NaN  NaN       NaN
#
#       Regionname  Propertycount  Distance CouncilArea
# 0            NaN            NaN       NaN         NaN
# ...

# %%
# Clean the dataset so it doesn't have any null value again using any method
house_prices_cleaning = house_prices.dropna( how = 'any')
house_prices_cleaning
# Out:
#               Suburb           Address  Rooms Type      Price Method  \
# 0         Abbotsford     49 Lithgow St      3    h  1490000.0      S
# 1         Abbotsford     59A Turner St      3    h  1220000.0      S
# 2         Abbotsford     119B Yarra St      3    h  1420000.0      S
# 3         Aberfeldie        68 Vida St      3    h  1515000.0      S
# 4       Airport West  92 Clydesdale Rd      2    h   670000.0      S
# ...              ...               ...    ...  ...        ...    ...
# 63016      Frankston    4/34 Petrie St      2    u   347700.0     SP
# 63017        Preston     229 Murray Rd      3    h   808000.0      S
# 63018  Roxburgh Park         3 Carr Pl      3    h   566000.0      S
# 63019  Roxburgh Park       9 Parker Ct      3    h   500000.0      S
# 63020  Roxburgh Park    5 Parkinson Wy      3    h   545000.0      S
#
#         SellerG        Date  Postcode                  Regionname  \
# 0        Jellis   1/04/2017      3067       Northern Metropolitan
# ...

# %%
house_prices_cleaning = house_prices
house_prices
# Out:
#               Suburb           Address  Rooms Type      Price Method  \
# 0         Abbotsford     49 Lithgow St      3    h  1490000.0      S
# 1         Abbotsford     59A Turner St      3    h  1220000.0      S
# 2         Abbotsford     119B Yarra St      3    h  1420000.0      S
# 3         Aberfeldie        68 Vida St      3    h  1515000.0      S
# 4       Airport West  92 Clydesdale Rd      2    h   670000.0      S
# ...              ...               ...    ...  ...        ...    ...
# 63016      Frankston    4/34 Petrie St      2    u   347700.0     SP
# 63017        Preston     229 Murray Rd      3    h   808000.0      S
# 63018  Roxburgh Park         3 Carr Pl      3    h   566000.0      S
# 63019  Roxburgh Park       9 Parker Ct      3    h   500000.0      S
# 63020  Roxburgh Park    5 Parkinson Wy      3    h   545000.0      S
#
#         SellerG        Date  Postcode                  Regionname  \
# 0        Jellis   1/04/2017      3067       Northern Metropolitan
# ...

# %%
# Compute the sum, mean of the price column on the datas
Sum = house_prices.Price.sum()
Mean = house_prices.Price.mean()

print(Sum, '\n')
print(Mean)
# Out:
# 48331205530.0
#
# 997898.2414882415

# %%
# Get the house with the lowest price and with the highest price
Min_price = house_prices.Price.min()
Max_price = house_prices.Price.max()

print(Min_price, '\n')
print(Max_price)
# Out:
# 85000.0
#
# 11200000.0

# %%
house_prices.min()
# Out:
# Suburb                     Abbotsford
# Address              1 Abercrombie St
# Rooms                               1
# Type                                h
# Price                         85000.0
# Method                             PI
# SellerG                       @Realty
# Date                        1/04/2017
# Postcode                         3000
# Regionname       Eastern Metropolitan
# Propertycount                      39
# Distance                          0.0
# CouncilArea      Banyule City Council
# dtype: object

# %%
house_prices.max()
# Out:
# Suburb                             viewbank
# Address                         9c State St
# Rooms                                    31
# Type                                      u
# Price                            11200000.0
# Method                                   VB
# SellerG                         voglwalpole
# Date                              9/12/2017
# Postcode                               3980
# Regionname                 Western Victoria
# Propertycount                         21650
# Distance                               55.8
# CouncilArea      Yarra Ranges Shire Council
# dtype: object
