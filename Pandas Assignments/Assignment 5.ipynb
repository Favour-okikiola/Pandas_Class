# %%
import numpy as np
import pandas as pd

# %%
Hotel_Reviews = pd.read_csv('C:\DATA\Hotel_Reviews (1).csv')
Student_Dropout = pd.read_csv('C:\DATA\Student_Dropout (1).csv')
Telco_Customer_Churn = pd.read_csv('C:\DATA\Telco-Customer-Churn (1).csv')

# %% [markdown]
# # Analyzing  Hotel_Reviews dataset

# %%
# viewing the first 5 rows
Hotel_Reviews.head()
# Out:
#                                        Hotel_Address  \
# 0   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 1   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 2   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 3   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 4   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
#
#    Additional_Number_of_Scoring Review_Date  Average_Score   Hotel_Name  \
# 0                           194    8/3/2017            7.7  Hotel Arena
# 1                           194    8/3/2017            7.7  Hotel Arena
# 2                           194   7/31/2017            7.7  Hotel Arena
# 3                           194   7/31/2017            7.7  Hotel Arena
# 4                           194   7/24/2017            7.7  Hotel Arena
#
#   Reviewer_Nationality                                    Negative_Review  \
# 0              Russia    I am so angry that i made this post available...
# ...

# %%
# viewing the last 5 rows
Hotel_Reviews.tail()
# Out:
#                                             Hotel_Address  \
# 515733  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
# 515734  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
# 515735  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
# 515736  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
# 515737  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
#
#         Additional_Number_of_Scoring Review_Date  Average_Score  \
# 515733                           168   8/30/2015            8.1
# 515734                           168   8/22/2015            8.1
# 515735                           168   8/19/2015            8.1
# 515736                           168   8/17/2015            8.1
# 515737                           168    8/9/2015            8.1
#
#                    Hotel_Name Reviewer_Nationality  \
# 515733  Atlantis Hotel Vienna              Kuwait
# 515734  Atlantis Hotel Vienna             Estonia
# 515735  Atlantis Hotel Vienna               Egypt
# ...

# %%
Hotel_Reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 515738 entries, 0 to 515737
# Data columns (total 17 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   Hotel_Address                               515738 non-null  object
#  1   Additional_Number_of_Scoring                515738 non-null  int64
#  2   Review_Date                                 515738 non-null  object
#  3   Average_Score                               515738 non-null  float64
#  4   Hotel_Name                                  515738 non-null  object
#  5   Reviewer_Nationality                        515738 non-null  object
#  6   Negative_Review                             515738 non-null  object
#  7   Review_Total_Negative_Word_Counts           515738 non-null  int64
#  8   Total_Number_of_Reviews                     515738 non-null  int64
# ...

# %%
Hotel_Reviews.describe()
# Out:
#        Additional_Number_of_Scoring  Average_Score  \
# count                 515738.000000  515738.000000
# mean                     498.081836       8.397487
# std                      500.538467       0.548048
# min                        1.000000       5.200000
# 25%                      169.000000       8.100000
# 50%                      341.000000       8.400000
# 75%                      660.000000       8.800000
# max                     2682.000000       9.800000
#
#        Review_Total_Negative_Word_Counts  Total_Number_of_Reviews  \
# count                      515738.000000            515738.000000
# mean                           18.539450              2743.743944
# std                            29.690831              2317.464868
# min                             0.000000                43.000000
# 25%                             2.000000              1161.000000
# 50%                             9.000000              2134.000000
# ...

# %%
# checking for nan vlaue
Hotel_Reviews[Hotel_Reviews.isnull()].any()
# Out:
# Hotel_Address                                 False
# Additional_Number_of_Scoring                  False
# Review_Date                                   False
# Average_Score                                 False
# Hotel_Name                                    False
# Reviewer_Nationality                          False
# Negative_Review                               False
# Review_Total_Negative_Word_Counts             False
# Total_Number_of_Reviews                       False
# Positive_Review                               False
# Review_Total_Positive_Word_Counts             False
# Total_Number_of_Reviews_Reviewer_Has_Given    False
# Reviewer_Score                                False
# Tags                                          False
# days_since_review                             False
# lat                                           False
# lng                                           False
# dtype: bool

# %%
# checking Negative_Review colunmns
Hotel_Reviews['Negative_Review']
# Out:
# 0          I am so angry that i made this post available...
# 1                                               No Negative
# 2          Rooms are nice but for elderly a bit difficul...
# 3          My room was dirty and I was afraid to walk ba...
# 4          You When I booked with your company on line y...
#                                 ...
# 515733     no trolly or staff to help you take the lugga...
# 515734             The hotel looks like 3 but surely not 4
# 515735     The ac was useless It was a hot week in vienn...
# 515736                                          No Negative
# 515737         I was in 3rd floor It didn t work Free Wife
# Name: Negative_Review, Length: 515738, dtype: object

# %%
Hotel_Reviews[Hotel_Reviews.columns].count()
# Out:
# Hotel_Address                                 515738
# Additional_Number_of_Scoring                  515738
# Review_Date                                   515738
# Average_Score                                 515738
# Hotel_Name                                    515738
# Reviewer_Nationality                          515738
# Negative_Review                               515738
# Review_Total_Negative_Word_Counts             515738
# Total_Number_of_Reviews                       515738
# Positive_Review                               515738
# Review_Total_Positive_Word_Counts             515738
# Total_Number_of_Reviews_Reviewer_Has_Given    515738
# Reviewer_Score                                515738
# Tags                                          515738
# days_since_review                             515738
# lat                                           512470
# lng                                           512470
# dtype: int64

# %%
Hotel_Reviews.shape
# Out:
# (515738, 17)

# %%
# getting the names of the hotels
Hotel_Reviews['Hotel_Name'].unique()
# Out:
# array(['Hotel Arena', 'K K Hotel George', 'Apex Temple Court Hotel', ...,
#        'The Berkeley', 'Holiday Inn London Kensington',
#        'Atlantis Hotel Vienna'], dtype=object)

# %%
Hotel_Reviews.groupby('Hotel_Address')

# %%
Hotel_Reviews.groupby('Hotel_Name').count()
# Out:
#                                     Hotel_Address  \
# Hotel_Name
# 11 Cadogan Gardens                            159
# 1K Hotel                                      148
# 25hours Hotel beim MuseumsQuartier            689
# 41                                            103
# 45 Park Lane Dorchester Collection             28
# ...                                           ...
# citizenM London Bankside                     1517
# citizenM London Shoreditch                    838
# citizenM Tower of London                     1683
# every hotel Piccadilly                        568
# pentahotel Vienna                             129
#
#                                     Additional_Number_of_Scoring  Review_Date  \
# Hotel_Name
# 11 Cadogan Gardens                                           159          159
# 1K Hotel                                                     148          148
# 25hours Hotel beim MuseumsQuartier                           689          689
# ...

# %%
Hotel_Reviews.groupby('Hotel_Address')['Reviewer_Nationality'].head()
# Out:
# 0                  Russia
# 1                 Ireland
# 2               Australia
# 3          United Kingdom
# 4             New Zealand
#                 ...
# 515413     United Kingdom
# 515414               Oman
# 515415              Malta
# 515416            Austria
# 515417             Norway
# Name: Reviewer_Nationality, Length: 7465, dtype: object

# %%
Hotel_Reviews.groupby('Hotel_Address')['Average_Score'].describe()
# Out:
#                                                      count  mean  \
# Hotel_Address
#  s Gravesandestraat 55 Oost 1092 AA Amsterdam N...   405.0   7.7
# 1 15 Templeton Place Earl s Court Kensington an...   566.0   8.5
# 1 2 Serjeant s Inn Fleet Street City of London ...  1037.0   9.2
# 1 3 Queens Garden Westminster Borough London W2...  1770.0   7.7
# 1 3 Rue d Argentine 16th arr 75116 Paris France       35.0   8.4
# ...                                                    ...   ...
# Wiedner Hauptstra e 44 04 Wieden 1040 Vienna Au...   439.0   8.0
# Wildpretmarkt 5 01 Innere Stadt 1010 Vienna Aus...   144.0   8.9
# Wilton Place Knightsbridge Westminster Borough ...   100.0   9.1
# Wrights Lane Kensington and Chelsea London W8 5...  2768.0   7.8
# Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 V...   325.0   8.1
#
#                                                              std  min  25%  \
# Hotel_Address
#  s Gravesandestraat 55 Oost 1092 AA Amsterdam N...  4.179602e-14  7.7  7.7
# ...

# %% [markdown]
# # Analyzing Student_Dropout dataset

# %%
# viewing the first 5 rows
Student_Dropout.head()
# Out:
#    Marital status  Application mode  Application order  Course  \
# 0               1                17                  5     171
# 1               1                15                  1    9254
# 2               1                 1                  5    9070
# 3               1                17                  2    9773
# 4               2                39                  1    8014
#
#    Daytime/evening attendance\t  Previous qualification  \
# 0                             1                       1
# 1                             1                       1
# 2                             1                       1
# 3                             1                       1
# 4                             0                       1
#
#    Previous qualification (grade)  Nacionality  Mother's qualification  \
# 0                           122.0            1                      19
# 1                           160.0            1                       1
# ...

# %%
Student_Dropout['Application mode'].unique()
# Out:
# array([17, 15,  1, 39, 18, 53, 44, 51, 43,  7, 42, 16,  5,  2, 10, 57, 26,
#        27], dtype=int64)

# %%
# viewing the last 5 rows
Student_Dropout.tail()
# Out:
#       Marital status  Application mode  Application order  Course  \
# 4419               1                 1                  6    9773
# 4420               1                 1                  2    9773
# 4421               1                 1                  1    9500
# 4422               1                 1                  1    9147
# 4423               1                10                  1    9773
#
#       Daytime/evening attendance\t  Previous qualification  \
# 4419                             1                       1
# 4420                             1                       1
# 4421                             1                       1
# 4422                             1                       1
# 4423                             1                       1
#
#       Previous qualification (grade)  Nacionality  Mother's qualification  \
# 4419                           125.0            1                       1
# ...

# %%
Student_Dropout.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4424 entries, 0 to 4423
# Data columns (total 37 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Marital status                                  4424 non-null   int64
#  1   Application mode                                4424 non-null   int64
#  2   Application order                               4424 non-null   int64
#  3   Course                                          4424 non-null   int64
#  4   Daytime/evening attendance	                     4424 non-null   int64
#  5   Previous qualification                          4424 non-null   int64
#  6   Previous qualification (grade)                  4424 non-null   float64
#  7   Nacionality                                     4424 non-null   int64
#  8   Mother's qualification                          4424 non-null   int64
# ...

# %%
Student_Dropout.describe()
# Out:
#        Marital status  Application mode  Application order       Course  \
# count     4424.000000       4424.000000        4424.000000  4424.000000
# mean         1.178571         18.669078           1.727848  8856.642631
# std          0.605747         17.484682           1.313793  2063.566416
# min          1.000000          1.000000           0.000000    33.000000
# 25%          1.000000          1.000000           1.000000  9085.000000
# 50%          1.000000         17.000000           1.000000  9238.000000
# 75%          1.000000         39.000000           2.000000  9556.000000
# max          6.000000         57.000000           9.000000  9991.000000
#
#        Daytime/evening attendance\t  Previous qualification  \
# count                   4424.000000             4424.000000
# mean                       0.890823                4.577758
# std                        0.311897               10.216592
# min                        0.000000                1.000000
# ...

# %%
# checking for null value
Student_Dropout[Student_Dropout.isnull()].any()
# Out:
# Marital status                                    False
# Application mode                                  False
# Application order                                 False
# Course                                            False
# Daytime/evening attendance\t                      False
# Previous qualification                            False
# Previous qualification (grade)                    False
# Nacionality                                       False
# Mother's qualification                            False
# Father's qualification                            False
# Mother's occupation                               False
# Father's occupation                               False
# Admission grade                                   False
# Displaced                                         False
# Educational special needs                         False
# Debtor                                            False
# Tuition fees up to date                           False
# ...

# %%
Student_Dropout.shape
# Out:
# (4424, 37)

# %%
Student_Dropout.columns
# Out:
# Index(['Marital status', 'Application mode', 'Application order', 'Course',
#        'Daytime/evening attendance\t', 'Previous qualification',
#        'Previous qualification (grade)', 'Nacionality',
#        'Mother's qualification', 'Father's qualification',
#        'Mother's occupation', 'Father's occupation', 'Admission grade',
#        'Displaced', 'Educational special needs', 'Debtor',
#        'Tuition fees up to date', 'Gender', 'Scholarship holder',
#        'Age at enrollment', 'International',
#        'Curricular units 1st sem (credited)',
#        'Curricular units 1st sem (enrolled)',
#        'Curricular units 1st sem (evaluations)',
#        'Curricular units 1st sem (approved)',
#        'Curricular units 1st sem (grade)',
#        'Curricular units 1st sem (without evaluations)',
#        'Curricular units 2nd sem (credited)',
#        'Curricular units 2nd sem (enrolled)',
#        'Curricular units 2nd sem (evaluations)',
# ...

# %%
# Student_Dropout['Gender'] 

Student_Dropout.groupby('Target')[['Daytime/evening attendance\t']].sum()
# Out:
#           Daytime/evening attendance\t
# Target
# Dropout                           1214
# Enrolled                           719
# Graduate                          2008

# %% [markdown]
# # ############Student_Dropout dataset#########

# %%
# the most registered course

courses = Student_Dropout['Course'].value_counts()
print(courses, "\n")

most_registered_course = courses.idxmax()  #indexmax()
courses_count = courses.max()

print(f"The most registered course is: {most_registered_course} with {courses_count}  number of students" )
# Out:
# Course
# 9500    766
# 9147    380
# 9238    355
# 9085    337
# 9773    331
# 9670    268
# 9991    268
# 9254    252
# 9070    226
# 171     215
# 8014    215
# 9003    210
# 9853    192
# 9119    170
# 9130    141
# 9556     86
# 33       12
# Name: count, dtype: int64
#
# The most registered course is: 9500 with 766  number of students

# %%
# The most application mode

application_mode = Student_Dropout['Application mode'].value_counts()
print(application_mode, '\n')

most_application_mode = application_mode.idxmax()
application_mode_count = application_mode.max()

print(f"The most common application mode is: {most_application_mode} with {application_mode_count} applications.")
# Out:
# Application mode
# 1     1708
# 17     872
# 39     785
# 43     312
# 44     213
# 7      139
# 18     124
# 42      77
# 51      59
# 16      38
# 53      35
# 15      30
# 5       16
# 10      10
# 2        3
# 57       1
# 26       1
# 27       1
# Name: count, dtype: int64
#
# The most common application mode is: 1 with 1708 applications.

# %%
# nationality with the higest student
nationality = Student_Dropout['Nacionality'].value_counts()
print(nationality, '\n')

highest_nationality = nationality.idxmax()
highest_nationality_students = nationality.max()

print(f"nationality with the highest student is {highest_nationality} with {highest_nationality_students} students")
# Out:
# Nacionality
# 1      4314
# 41       38
# 26       14
# 22       13
# 6        13
# 24        5
# 100       3
# 11        3
# 103       3
# 21        2
# 101       2
# 62        2
# 25        2
# 2         2
# 105       2
# 32        1
# 13        1
# 109       1
# 108       1
# 14        1
# 17        1
# Name: count, dtype: int64
#
# nationality with the highest student is 1 with 4314 students

# %%
Student_Dropout['Target'].unique()
# Out:
# array(['Dropout', 'Graduate', 'Enrolled'], dtype=object)

# %%
#total number of students in the school
Student_Dropout['Target'].count()
# Out:
# 4424

# %%
# number of student that enrolled 

num_Enrolled = (Student_Dropout['Target'] == 'Enrolled').sum()

print(f"The number of students who enrolled is: {num_Enrolled}")
# Out:
# The number of students who enrolled is: 794

# %%
# number of student that graduated

num_graduates = (Student_Dropout['Target'] == 'Graduate').sum()


print(f"The number of students who graduated is: {num_graduates}")

# checking
#(Student_Dropout['Target'] == 'Graduate').value_counts()
# Out:
# The number of students who graduated is: 2209

# %%
# number of student that dropout

num_Dropout = (Student_Dropout['Target'] == 'Dropout').sum()
num_Dropout

print(f"The number of students who Dropout is: {num_Dropout}")

#(Student_Dropout['Target'] == 'Dropout').value_counts()
# Out:
# The number of students who Dropout is: 1421

# %%
Student_Dropout.groupby('Target')['Course'].count()
# Out:
# Target
# Dropout     1421
# Enrolled     794
# Graduate    2209
# Name: Course, dtype: int64

# %%
Student_Dropout.shape
# Out:
# (4424, 37)

# %%
Student_Dropout['Age at enrollment'].describe()
# Out:
# count    4424.000000
# mean       23.265145
# std         7.587816
# min        17.000000
# 25%        19.000000
# 50%        20.000000
# 75%        25.000000
# max        70.000000
# Name: Age at enrollment, dtype: float64

# %%
# mean age of enrollment of student

mean_age = Student_Dropout['Age at enrollment'].mean()

print(f"The mean age of enrollment for students is: {mean_age:.0f}")  # rounding it up to 0 decimal place
# Out:
# The mean age of enrollment for students is: 23

# %%
# max age of enrollment of student

max_age = Student_Dropout['Age at enrollment'].max()

print(f"The maximum age of enrollment for students is: {max_age:.0f}")
# Out:
# The maximum age of enrollment for students is: 70

# %%
# min age of enrollment of student

min_age = Student_Dropout['Age at enrollment'].min()

print(f"The minimum age of enrollment for students is: {min_age:.0f}")
# Out:
# The minimum age of enrollment for students is: 17

# %%
Student_Dropout['Daytime/evening attendance\t'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
# what part of the day do they attend classes most

Student_Dropout['Daytime/evening attendance\t'].describe()
# Out:
# count    4424.000000
# mean        0.890823
# std         0.311897
# min         0.000000
# 25%         1.000000
# 50%         1.000000
# 75%         1.000000
# max         1.000000
# Name: Daytime/evening attendance\t, dtype: float64

# %%
attendance  = Student_Dropout['Daytime/evening attendance\t'].max()

print(f"The part of the day students do attend classes most is : {attendance}")
# Out:
# The part of the day students do attend classes most is : 1

# %%
attendance_counts = Student_Dropout['Daytime/evening attendance\t'].value_counts()
print(attendance_counts, '\n')

# Finding the part of the day with the highest attendance
most_attendance = attendance_counts.idxmax()
most_attendance_count = attendance_counts.max()

print(f"The part of the day with the highest class attendance is: {most_attendance} with {most_attendance_count} students.")
# Out:
# Daytime/evening attendance\t
# 1    3941
# 0     483
# Name: count, dtype: int64
#
# The part of the day with the highest class attendance is: 1 with 3941 students.

# %%
# # how GPD, unemployment and inflation affect student from graduating 

# # Convert 'Target' to binary: 1 for 'Graduate', 0 for 'Dropout'
# Student_Dropout['Graduated'] = Student_Dropout['Target'].apply(lambda x: 1 if x == 'Graduate' else 0)

# # Calculate correlation matrix
# correlations = Student_Dropout[['Graduated', 'GDP', 'Unemployment rate', 'Inflation rate']].corr()

# print(correlations)

# %%
# Convert categorical columns to dummy variables
Student_Dropout_dummies = pd.get_dummies(Student_Dropout, drop_first=True)
# Student_Dropout_dummies

# Display the first few rows of the modified dataset
print(Student_Dropout_dummies.head())

# Select relevant columns for analysis
relevant_columns = ['GDP', 'Unemployment rate', 'Inflation rate', 'Target_Graduate']

# Create a new DataFrame with only the relevant columns
Student_Dropout_analysis = Student_Dropout_dummies[relevant_columns]

# Display the first few rows of the analysis DataFrame
print(Student_Dropout_analysis.head())
# Out:
#    Marital status  Application mode  Application order  Course  \
# 0               1                17                  5     171
# 1               1                15                  1    9254
# 2               1                 1                  5    9070
# 3               1                17                  2    9773
# 4               2                39                  1    8014
#
#    Daytime/evening attendance\t  Previous qualification  \
# 0                             1                       1
# 1                             1                       1
# 2                             1                       1
# 3                             1                       1
# 4                             0                       1
#
#    Previous qualification (grade)  Nacionality  Mother's qualification  \
# 0                           122.0            1                      19
# 1                           160.0            1                       1
# ...

# %%
Student_Dropout['Target']
# Out:
# 0        Dropout
# 1       Graduate
# 2        Dropout
# 3       Graduate
# 4       Graduate
#           ...
# 4419    Graduate
# 4420     Dropout
# 4421     Dropout
# 4422    Graduate
# 4423    Graduate
# Name: Target, Length: 4424, dtype: object

# %%
# mean approved score of 1st semester 
Student_Dropout['Curricular units 1st sem (approved)'].describe()
# Out:
# count    4424.000000
# mean        4.706600
# std         3.094238
# min         0.000000
# 25%         3.000000
# 50%         5.000000
# 75%         6.000000
# max        26.000000
# Name: Curricular units 1st sem (approved), dtype: float64

# %%
mean_score = Student_Dropout['Curricular units 1st sem (approved)'].mean()

print(f"mean approved score for 1st semester is {mean_score: .2f}")
# Out:
# mean approved score for 1st semester is  4.71

# %%
# mean approved score of 2nd semester 
Student_Dropout['Curricular units 2nd sem (approved)'].describe()
# Out:
# count    4424.000000
# mean        4.435805
# std         3.014764
# min         0.000000
# 25%         2.000000
# 50%         5.000000
# 75%         6.000000
# max        20.000000
# Name: Curricular units 2nd sem (approved), dtype: float64

# %%
mean_score = Student_Dropout['Curricular units 2nd sem (approved)'].mean()

print(f"mean approved score for 2nd semester is {mean_score: .2f}")
# Out:
# mean approved score for 2nd semester is  4.44

# %%
# number of approved student for 1st semester
Student_Dropout['Curricular units 1st sem (enrolled)'].describe()
# Out:
# count    4424.000000
# mean        6.270570
# std         2.480178
# min         0.000000
# 25%         5.000000
# 50%         6.000000
# 75%         7.000000
# max        26.000000
# Name: Curricular units 1st sem (enrolled), dtype: float64

# %%
approved_student =  Student_Dropout['Curricular units 1st sem (enrolled)'].count()
print(f" approved student for 1st semester is {approved_student}")
# Out:
#  approved student for 1st semester is 4424

# %%
# number of approved student for 1st semester
Student_Dropout['Curricular units 2nd sem (enrolled)'].describe()
# Out:
# count    4424.000000
# mean        6.232143
# std         2.195951
# min         0.000000
# 25%         5.000000
# 50%         6.000000
# 75%         7.000000
# max        23.000000
# Name: Curricular units 2nd sem (enrolled), dtype: float64

# %%
approved_student =  Student_Dropout['Curricular units 2nd sem (enrolled)'].count()
print(f" approved student for 2nd semester is {approved_student}")
# Out:
#  approved student for 2nd semester is 4424

# %%
# how many scholarship holder
Student_Dropout['Scholarship holder'].describe()
# Out:
# count    4424.000000
# mean        0.248418
# std         0.432144
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
# Name: Scholarship holder, dtype: float64

# %%
num_scholarship_holders = Student_Dropout['Scholarship holder'].value_counts()
num_scholarship_holders
# Out:
# Scholarship holder
# 0    3325
# 1    1099
# Name: count, dtype: int64

# %%
Student_Dropout['Scholarship holder'].unique()

# scholarship holder = 1
# non-scholarship holder = 0
# Out:
# array([0, 1], dtype=int64)

# %%
Student_Dropout['Scholarship holder'].sum()
# Out:
# 1099

# %%
# scholarship holder

(Student_Dropout['Scholarship holder']== 1).sum()
# Out:
# 1099

# %%
# non-scholarship holder

(Student_Dropout['Scholarship holder']== 0).sum()
# Out:
# 3325

# %%
# # how many scholarship holder graduated

# # Converting 'Target' to binary: 
# # 1 for 'Graduate'
# # 0 for 'Dropout'
# Student_Dropout['Graduated'] = Student_Dropout['Target'].apply(lambda x: 1 if x == 'Graduate' else 0)

# # Filter the dataset to include only scholarship holders
# scholarship_holders = Student_Dropout[Student_Dropout['Scholarship holder'] == 1]

# # Count the number of scholarship holders who graduated
# num_scholarship_holders_graduated = scholarship_holders['Graduated'].sum()

# print(f"The number of scholarship holders who graduated is: {num_scholarship_holders_graduated}")

# %%
# how many scholarship holder dropout

#Student_Dropout['Graduated'] = Student_Dropout['Target'].apply(lambda x: 1 if x == 'Graduate' else 0)

# Filter the dataset to include only scholarship holders
#scholarship_holders = Student_Dropout[Student_Dropout['Scholarship holder'] == 1]
scholarship_holders =Student_Dropout[Student_Dropout['Scholarship holder']== 1]
scholarship_holders
dropout = (scholarship_holders['Target']=='Dropout').sum()
print(f"number of dropout: {dropout}" , '\n')
enrolled = (scholarship_holders['Target']=='Enrolled').sum()
print(f"number of enrooled: {enrolled}", '\n')

# Count the number of scholarship holders who graduated
#num_scholarship_holders_graduated = scholarship_holders['Graduated'].sum()
#Student_Dropout[scholarship_holders]

#print(f"The number of scholarship holders who graduated is: {num_scholarship_holders_graduated}")
#scholarship_holders
# Out:
# number of dropout: 134
#
# number of enrooled: 130

# %%
# how many are not scholarship holder
# non-scholarship holder

non_scholarship_holders = (Student_Dropout['Scholarship holder']== 0).sum()
non_scholarship_holders
# Out:
# 3325

# %%
# is there tuition up to date
non_scholarship_holders = Student_Dropout[Student_Dropout['Scholarship holder'] == 0 ]
# non_scholarship_holders
                                          
tuition_up_to_date = non_scholarship_holders['Tuition fees up to date'].sum()
# tuition_up_to_date
print(tuition_up_to_date)
# Out:
# 2843

# %%
# Tuition fees up to date for NON-SCHOLARSHIP HOLDERS AND SCHOLARSHIP HOLDER
tuition_up_to_date = non_scholarship_holders['Tuition fees up to date'].value_counts()
# tuition_up_to_date
print(tuition_up_to_date)
# Out:
# Tuition fees up to date
# 1    2843
# 0     482
# Name: count, dtype: int64

# %% [markdown]
# #    ################|||||||||||||##############

# %% [markdown]
# #  Analyzing Telco_Customer_Churn dataset

# %%
Telco_Customer_Churn
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
# viewing the first 5 rows
Telco_Customer_Churn.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
# viewing the first 5 rows
Telco_Customer_Churn.tail()
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 7038          Yes               Yes             DSL            Yes  ...
# 7039          Yes               Yes     Fiber optic             No  ...
# 7040           No  No phone service             DSL            Yes  ...
# 7041          Yes               Yes     Fiber optic             No  ...
# 7042          Yes                No     Fiber optic            Yes  ...
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %%
Telco_Customer_Churn.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
# checking for null value
Telco_Customer_Churn[Telco_Customer_Churn.isnull()].any()
# Out:
# customerID          False
# gender              False
# SeniorCitizen       False
# Partner             False
# Dependents          False
# tenure              False
# PhoneService        False
# MultipleLines       False
# InternetService     False
# OnlineSecurity      False
# OnlineBackup        False
# DeviceProtection    False
# TechSupport         False
# StreamingTV         False
# StreamingMovies     False
# Contract            False
# PaperlessBilling    False
# PaymentMethod       False
# MonthlyCharges      False
# TotalCharges        False
# Churn               False
# dtype: bool

# %%
Telco_Customer_Churn.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
Telco_Customer_Churn.shape
# Out:
# (7043, 21)

# %%
Telco_Customer_Churn['gender']
# Out:
# 0       Female
# 1         Male
# 2         Male
# 3         Male
# 4       Female
#          ...
# 7038      Male
# 7039    Female
# 7040    Female
# 7041      Male
# 7042      Male
# Name: gender, Length: 7043, dtype: object

# %%
Telco_Customer_Churn['gender'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
# counting the numbers of male in the dataset
Telco_Customer_Churn[Telco_Customer_Churn['gender'] == 'Male'].count()
# Out:
# customerID          3555
# gender              3555
# SeniorCitizen       3555
# Partner             3555
# Dependents          3555
# tenure              3555
# PhoneService        3555
# MultipleLines       3555
# InternetService     3555
# OnlineSecurity      3555
# OnlineBackup        3555
# DeviceProtection    3555
# TechSupport         3555
# StreamingTV         3555
# StreamingMovies     3555
# Contract            3555
# PaperlessBilling    3555
# PaymentMethod       3555
# MonthlyCharges      3555
# TotalCharges        3555
# Churn               3555
# dtype: int64

# %%
# counting the numbers of female in the dataset
Telco_Customer_Churn[Telco_Customer_Churn['gender'] == 'Female'].count()
# Out:
# customerID          3488
# gender              3488
# SeniorCitizen       3488
# Partner             3488
# Dependents          3488
# tenure              3488
# PhoneService        3488
# MultipleLines       3488
# InternetService     3488
# OnlineSecurity      3488
# OnlineBackup        3488
# DeviceProtection    3488
# TechSupport         3488
# StreamingTV         3488
# StreamingMovies     3488
# Contract            3488
# PaperlessBilling    3488
# PaymentMethod       3488
# MonthlyCharges      3488
# TotalCharges        3488
# Churn               3488
# dtype: int64

# %%
# How many use streamingTV
Telco_Customer_Churn[Telco_Customer_Churn['StreamingTV'] == 'Yes'].count()
# Out:
# customerID          2707
# gender              2707
# SeniorCitizen       2707
# Partner             2707
# Dependents          2707
# tenure              2707
# PhoneService        2707
# MultipleLines       2707
# InternetService     2707
# OnlineSecurity      2707
# OnlineBackup        2707
# DeviceProtection    2707
# TechSupport         2707
# StreamingTV         2707
# StreamingMovies     2707
# Contract            2707
# PaperlessBilling    2707
# PaymentMethod       2707
# MonthlyCharges      2707
# TotalCharges        2707
# Churn               2707
# dtype: int64

# %%
# How many do not use streamingTV
Telco_Customer_Churn[Telco_Customer_Churn['StreamingTV'] == 'No'].count()
# Out:
# customerID          2810
# gender              2810
# SeniorCitizen       2810
# Partner             2810
# Dependents          2810
# tenure              2810
# PhoneService        2810
# MultipleLines       2810
# InternetService     2810
# OnlineSecurity      2810
# OnlineBackup        2810
# DeviceProtection    2810
# TechSupport         2810
# StreamingTV         2810
# StreamingMovies     2810
# Contract            2810
# PaperlessBilling    2810
# PaymentMethod       2810
# MonthlyCharges      2810
# TotalCharges        2810
# Churn               2810
# dtype: int64

# %%
Telco_Customer_Churn.groupby('gender')

# %%
# numbers of genders across the dataset
Telco_Customer_Churn.groupby('gender').count()
# Out:
#         customerID  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# gender
# Female        3488           3488     3488        3488    3488          3488
# Male          3555           3555     3555        3555    3555          3555
#
#         MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# gender
# Female           3488             3488            3488          3488
# Male             3555             3555            3555          3555
#
#         DeviceProtection  TechSupport  StreamingTV  StreamingMovies  Contract  \
# gender
# Female              3488         3488         3488             3488      3488
# Male                3555         3555         3555             3555      3555
#
#         PaperlessBilling  PaymentMethod  MonthlyCharges  TotalCharges  Churn
# gender
# Female              3488           3488            3488          3488   3488
# Male                3555           3555            3555          3555   3555

# %%
# how many of the them are dependent
Telco_Customer_Churn.groupby('gender')[['Dependents']].count()
# Out:
#         Dependents
# gender
# Female        3488
# Male          3555

# %%
Telco_Customer_Churn.groupby('Dependents')[['gender']].count()
# Out:
#             gender
# Dependents
# No            4933
# Yes           2110

# %%
Telco_Customer_Churn.groupby('DeviceProtection')[['gender']].count()
# Out:
#                      gender
# DeviceProtection
# No                     3095
# No internet service    1526
# Yes                    2422
